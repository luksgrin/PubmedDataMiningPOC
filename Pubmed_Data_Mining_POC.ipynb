# %% [markdown]
# # Pubmed Data Mining
#
# _Lucas Goiriz Beltrán_
#
# Para hacer este análisis, vamos a usar:
# - `ENTREZ`: la API para hacer consultas a Pubmed
# - `requests`: para hacer solicitudes HTTP a la API
# - `json`: para interactuar con las respuestas de la API
# - `xml`: para interactuar con las respuestas de la API en el caso en el que `json` no sea posible.
# - `pandas`: para crear las tablas de datos (ojo que para convertir a `.xlsx`, por debajo `pandas` usa `openpyxl`).

# %%
# Vamos a cargar las librerías
import requests, json, xml
import xml.etree.ElementTree as ET
import pandas as pd

# %%
# API de ENTREZ. Vease https://www.ncbi.nlm.nih.gov/books/NBK25499/
esearchApi = r"http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi" # Para la consulta en Pubmed
efetchApi  = r"http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"  # Para obtener los datos de los artículos
efetchPost = r"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/epost.fcgi"  # En caso de que la consulta sea grande para efetch

# Atributos de la consulta

attbs = {
    "db"       : "pubmed",     # La base de datos a consultar: Pubmed
    "retmode"  : "json",       # Queremos que nos devuelva todo en formato json, porque para mí es más sencillo
    "retmax"   : "50000",      # Queremos que como máximo nos devuelva 50000 resultados
    "datetype" : "pdat",       # El tipo de fecha: pdat es fecha de publicación
    "mindate"  : "2022/01/01", # Fecha mínima, en formato AAAA/MM/DD
    "maxdate"  : "2022/12/31", # Fecha mínima, en formato AAAA/MM/DD
    "term"     : "polylysine"  # El término de búsqueda (admite más, separados por comas)
}

# Construimos la URL
URL1 = esearchApi + "?"

for k,v in attbs.items():
    URL1 += ("%s=%s&" % (k, v))
URL1 = URL1[:-1]

print("La URL de nuestra búsqueda en pubmed es:\n%s" % URL1)
# Out:
# La URL de nuestra búsqueda en pubmed es:
# http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&retmode=json&retmax=50000&datetype=pdat&mindate=2022/01/01&maxdate=2022/12/31&term=polylysine

# %%
"""Nos generamos una función para hacer la consulta que nos devuelva además
si la consulta ha tenido éxito. La usaremos luego de nuevo
"""

def queryNstatus(URL):
    
    # Hacemos la consulta
    query = requests.get(URL)

    # Miramos a ver si hemos tenido éxito
    if query.status_code == 200:
        print("La consulta ha sido exitosa")

    else:
        print("La consulta no ha sido exitosa")
        
    return query

# Lanzamos la función
queryOutput = queryNstatus(URL1)
# Out:
# La consulta ha sido exitosa

# %%
# En caso de que la consulta haya sido exitosa,
# Extraemos los IDs de los artículos de interés
resultados = json.loads(queryOutput.text)
articleIDs = resultados["esearchresult"]["idlist"]

# Parámetros de la segunda consulta
pars = ["db", "pubmed", "retmode", "xml"]

# Si hay muchos resultados
if len(articleIDs) > 199:
    # Hacemos una solicitud POST
    postreq = requests.post(efetchPost, data={"id":",".join(articleIDs)})
    
    # Si esta sale bien
    if postreq.status_code == 200:
        print("La llamada POST ha sido exitosa")
        
        # Añadimos la query_key y la WebEnv a los parámetros de consulta
        qkeys = ET.fromstring(postreq.text)
        
        URL2 = (
            (efetchApi + "?%s=%s&%s=%s&%s=%s&%s=%s&")
            % tuple(pars + ["query_key", qkeys[0].text, "WebEnv", qkeys[1].text])
        )[:-1]

    else:
        print("La llamada POST no ha sido exitosa")
        URL2 = ''

else:
    URL2 = (efetchApi + "?%s=%s&%s=%s&") % ("db", "pubmed", "retmode", "xml")
    URL2 += ("id=" + ",".join(articleIDs))

if URL2:    
    # Hacemos la consulta   
    queryOutput = queryNstatus(URL2)
# Out:
# La consulta ha sido exitosa

# %% [markdown]
# Si la consulta ha sido exitosa, cargamos el xml

# %%
XMLroot = ET.fromstring(queryOutput.text)

# Rellenamos un diccionario con
# Título de publicación : [Num Afiliaciones, Afiliaciones, Abstract, URL]
datos = {}
nonArticles = []

for element in XMLroot:

    # En caso de ser un artículo, buscamos el título
    if element.tag == 'PubmedArticle':
        title = element.findall(".//ArticleTitle")[0].text
        
    else:
        nonArticles.append(element.tag)
        continue
    
    # Buscamos las diferentes afiliaciones
    affs = set([aff[0].text for aff in element.findall(".//AffiliationInfo")])

    # Buscamos el doi, para poder acceder al artículo luego
    doi = next( # Tomamos el primer elemeto del iterador ...
        filter( # creamos un iterador que surja a partir de filtrar una lista
            lambda x: ( # devuelve True si el atributo del element es doi y es válido
                (x.attrib["EIdType"] == "doi")
                and (x.attrib["ValidYN"] == "Y")
            ),
            element.findall(".//ELocationID") # lista de tags ELocationID
        ),
        None
    )
    
    # Si el doi existe, añade el resto de la url
    if doi != None:
        doi = "https://doi.org/" + doi.text

    # Guardamos la información de interés
    datos[title] = [
        len(affs), # Número de afiliaciones
        "\n".join(affs), # Afiliaciones
        element.findall(".//AbstractText")[0].text, # Texto del Abstract
        r"https://pubmed.ncbi.nlm.nih.gov/%s/" % element.findall(".//PMID")[0].text, # PMID
        doi # DOI
    ]
    
if len(nonArticles) != 0:
    print(
        "Hay %d resultados que no son artículos."
        " Entre ellos están los siguientes tipos:\n"
        % len(nonArticles)
    )
    print(
        len(set(nonArticles))*"- %s\n"
        % tuple(set(nonArticles))
    )

# %% [markdown]
# # Creamos un `DataFrame` de pandas para poder visualizar los datos en una tabla

# %%
df = pd.DataFrame.from_dict(
    datos,
    orient  = "index",
    columns = ("NumAff", "Affiliations", "Abstract", "PMID", "DOI")
)
df.rename_axis("Title", inplace=True)
df.reset_index(inplace=True)
df
# Out:
#                                                 Title  NumAff  \
# 0   Development and characterization of levan/pull...       2
# 1   Long-Chain Poly-d-Lysines Interact with the Pl...       1
# 2   Poly-L-Lysine-Based αGal-Glycoconjugates for T...      12
# 3   A poly-l-lysine-bonded TEMPO-oxidized bacteria...       3
# 4   Effect of FLOT2 Gene Expression on Invasion an...       2
# 5   AdpA, a developmental regulator, promotes ε-po...       4
# 6   Antibacterial dialdehyde sodium alginate/ε-pol...       4
# 7   Effect of crosslinking strategy on the biologi...       4
# 8   Inkjet-Patterned Microdroplets as Individual M...       2
# 9   Construction of Intelligent Responsive Drug De...       5
# 10  Preparation and Properties of Pea Starch/ε-Pol...       2
# 11  Multi-omics reveals host metabolism associated...       1
# 12  Peptide-Engineered AIE Nanofibers with Excelle...       3
# 13  Blocking viral infections with lysine-based po...       3
# 14  Structure, stability, rheology, and texture pr...       2
# 15  Poly-l-lysine/Laminin Surface Coating Reverses...       4
# 16  Synergetic integrations of bone marrow stem ce...       3
# 17  Polylysine dendrigraft is able to differential...       4
# 18  NIPAm-Based Modification of Poly(L-lysine): A ...       2
# 19  Poly(ε-L-lysine) and poly(L-diaminopropionic a...       2
# 20  A fluorescent biosensor based on quantum dot-l...       3
# 21  Open tubular nano-liquid chromatography with a...       3
# 22  Poly-L-Lysine-Lactobionic Acid-Capped Selenium...       1
# 23  Measurement of Secondary Structure Changes in ...       2
# 24  Starch/PBAT blown antimicrobial films based on...       2
# 25  Metabolomics analysis of freeze-thaw tolerance...       2
# 26  Preparation and characterization of bifunction...       4
# 27  Polylysine for skin regeneration: A review of ...      11
# 28  Crystal structure of the adenylation domain fr...       5
# 29  Low-Molecular-Weight Polylysines with Excellen...       6
# 30  Wash-Free, Sandwich-Type Protein Detection Usi...       1
# 31  Fabrication of Epsilon-Polylysine-Based Magnet...       3
# 32  Poly-l-Lysine-Modified Graphene Field-Effect T...       2
# 33  Amoebicidal Activity of Poly-Epsilon-Lysine Fu...       4
# 34  Screening biofilm eradication activity of etha...       2
# 35  Low temperature extrusion blown ε-polylysine h...       4
# 36  Electrostatically self-assembled filamentous s...       6
# 37  Fabrication of Poly-l-lysine-Functionalized Gr...       1
# 38  Development of Icephilic ACTIVE Glycopeptides ...       3
# 39  Programmable Electrodeposition of Janus Algina...       4
# 40  Facile and green synthesis of reduced graphene...       5
# 41  Utility of carboxylated poly L-lysine for the ...       4
# 42  Randomized trial of neoadjuvant vaccination wi...       9
# 43  Reversible electrochemical triggering and opti...       4
# 44  Investigating histidinylated highly branched p...       3
# 45  Chitosan utilized for bacterial preparation fo...       3
# 46  A spatiotemporal release platform based on pH/...       4
# 47  Anti-adhesive effect of chondrocyte-derived ex...       6
# 48  High Pressure Thermal Sterilization and ε-Poly...       1
# 49  Antibacterial activity and action mechanism of...       2
# 50  Precise Diabetic Wound Therapy: PLS Nanosphere...       3
# 51  Preparation and characterization of gelatin/ze...       4
# 52  Effects of ethanol stress on epsilon-poly-l-ly...       3
# 53  Microencapsulation of functional ovalbumin and...       3
# 54  Influence of enantiomeric polylysine grafted o...       1
#
#                                          Affiliations  \
# 0   College of Biomass Science and Engineering, Si...
# 1   State Key Laboratory of Bioelectronics, School...
# 2   MEGA: Asthma Inception and Progression Mechani...
# 3   Microbiological Engineering and Industrial Bio...
# 4   Department of Gastrointestinal Surgery, The Fi...
# 5   Key Laboratory of Molecular Microbiology and T...
# 6   College of Chemistry and Environment Protectio...
# 7   AO Research Institute Davos, Clavadelerstrasse...
# 8   Department of Chemistry, Beijing Key Laborator...
# 9   Department of Respiratory Medicine, The First ...
# 10  School of Innovation & Entrepreneurship, Zheji...
# 11  Institute of Bast Fiber Crops, Chinese Academy...
# 12  Key Laboratory of Biomedical Engineering of Gu...
# 13  ViroStatics srl, Viale Umberto I, 46, 07100 Sa...
# 14  College of Food Science and Biotechnology Engi...
# 15  Univ. Grenoble Alps, CNRS, Grenoble INP, Insti...
# 16  Department of Sports Medicine and Joint Surger...
# 17  Laboratoire de Microbiologie Signaux et Microe...
# 18  Department of Chemical Engineering, University...
# 19  School of Food Science and Pharmaceutical Engi...
# 20  Department of Analytical Chemistry, Faculty of...
# 21  Food Analysis and Research Laboratory, Bingöl ...
# 22  Nano-Gene and Drug Delivery Group, Discipline ...
# 23  Lehrstuhl für Technische Thermodynamik (LTT), ...
# 24  College of Food Science and Engineering, Shand...
# 25  State Key Laboratory of Food Science and Techn...
# 26  Key Laboratory of Carbohydrate Chemistry and B...
# 27  Medical Mycology and Bacteriology Research Cen...
# 28  Department of Chemistry and Biotechnology, Gra...
# 29  Department of Ophthalmology, The Second Hospit...
# 30  Department of Chemistry and Chemistry Institut...
# 31  College of Food Science and Engineering, North...
# 32  State Key Laboratory of Crystal Materials, Sha...
# 33  Department of Eye and Vision Science, Institut...
# 34  Fukuoka Industrial Technology Center, Biotechn...
# 35  Department of Food Science, University of Guel...
# 36  School of Perfume and Aroma Technology, Shangh...
# 37  Department of Pharmaceutical Chemistry, H. R. ...
# 38  School of Materials Science and Engineering, T...
# 39  Shenzhen Key Laboratory of Biomimetic Robotics...
# 40  College of Food Science and Light Industry, Na...
# 41  Kagoshima City Aquarium, Kagoshima, Japan.\nJo...
# 42  Department of Respiratory Medicine & Rheumatol...
# 43  Dept. Of Molecular, Cellular and Development B...
# 44  Division of Molecular Therapeutics and Formula...
# 45  Core Facilities of West China Hospital, Sichua...
# 46  Department of Orthopedics, Orthopedic Research...
# 47  Department of Orthopedic Surgery, School of Me...
# 48  School of Food and Wine Science, Ningxia Unive...
# 49  School of Food Science and Biotechnology, Zhej...
# 50  Department of Orthopedic Trauma, Renji Hospita...
# 51  Institute of Agricultural Products Processing,...
# 52  College of Food and Bioengineering, Henan Univ...
# 53  School of Life Sciences, Anhui University, Hef...
# 54  MOE Key Laboratory of Macromolecular Synthesis...
#
#                                              Abstract  \
# 0   The levan/pullulan/chitosan edible films, enri...
# 1   Polylysines have been frequently used in drug ...
# 2   Anti-αGal IgE antibodies mediate a spreading a...
# 3   Oxidized bacterial nanocellulose (O-BNC) is a ...
# 4   The study is aimed at investigating the effect...
# 5   AdpA is a global regulator of morphological di...
# 6   Food security is an important global public he...
# 7   The design of multifunctional hydrogels based ...
# 8   Adhesion of single cells is the foundation of ...
# 9   Cancer remains a formidable global problem wit...
# 10  The composite films comprising pea starch (St)...
# 11  This study aimed to assess the influence of di...
# 12  Photosensitizers with aggregation-induced emis...
# 13  The outbreak of the Covid-19 pandemic due to t...
# 14  ε-Polylysine (ε-PL) is a natural preservative ...
# 15  Brain tissues demonstrate heterogeneous mechan...
# 16  The cartilage repair and regeneration show ina...
# 17  With a view to reducing the impact of Cutibact...
# 18  Polylysine is a biocompatible, biodegradable, ...
# 19  Poly(ε-L-lysine) and poly(L-diaminopropionic a...
# 20  Salmonella, as a common foodborne pathogen in ...
# 21  In this study, a novel narrow capillary (i.e.,...
# 22  Liver cancer is currently regarded as the seco...
# 23  Drying processes such as spray drying, as comm...
# 24  In this study, starch/PBAT antimicrobial film,...
# 25  Antimicrobial polycationic peptide ε-poly-l-ly...
# 26  A gellan-polylysine (GPL) fiber was prepared b...
# 27  There have been several attempts to find promi...
# 28  ε-poly-l-lysine (ε-PL) synthetase (Pls) is a m...
# 29  The steady development of bacterial resistance...
# 30  Direct electron transfer (DET) between a redox...
# 31  The risk of fruit juice contamination caused b...
# 32  (Mi)RNAs are important biomarkers for cancers ...
# 33  To determine the amoebicidal activity of funct...
# 34  The ethanol extracts of 155 different foodstuf...
# 35  Edible antimicrobial films made from starch/ge...
# 36  In the work, a novel filamentou sodium alginat...
# 37  The diagnosis of tumor biomarkers is an attent...
# 38  Ice formation and recrystallization exert seve...
# 39  Encapsulation of live cells in protective, sem...
# 40  Facile and green fabrication of reduced graphe...
# 41  Assisted reproduction techniques are required ...
# 42  BACKGROUNDLong-term prognosis of WHO grade II ...
# 43  Reversible electrochemical triggering of the r...
# 44  The temporary silencing of disease-associated ...
# 45  Bacterial sample preparation is crucial for it...
# 46  Fabricating injectable hydrogel with multifunc...
# 47  After an injury, soft tissue structures in the...
# 48  This study was conducted to determine the ster...
# 49  With the aim of exploring the potential applic...
# 50  Diabetic ulcers, a difficult problem faced by ...
# 51  Three edible food packaging films loaded with ...
# 52  The aim of the study was to reveal the effects...
# 53  Overcoming harsh gastric environment is still ...
# 54  The macrophages take significant roles in home...
#
#                                          PMID  \
# 0   https://pubmed.ncbi.nlm.nih.gov/35447595/
# 1   https://pubmed.ncbi.nlm.nih.gov/35442635/
# 2   https://pubmed.ncbi.nlm.nih.gov/35432370/
# 3   https://pubmed.ncbi.nlm.nih.gov/35422281/
# 4   https://pubmed.ncbi.nlm.nih.gov/35419458/
# 5   https://pubmed.ncbi.nlm.nih.gov/35397580/
# 6   https://pubmed.ncbi.nlm.nih.gov/35395481/
# 7   https://pubmed.ncbi.nlm.nih.gov/35378161/
# 8   https://pubmed.ncbi.nlm.nih.gov/35362237/
# 9   https://pubmed.ncbi.nlm.nih.gov/35332623/
# 10  https://pubmed.ncbi.nlm.nih.gov/35329778/
# 11  https://pubmed.ncbi.nlm.nih.gov/35315841/
# 12  https://pubmed.ncbi.nlm.nih.gov/35307954/
# 13  https://pubmed.ncbi.nlm.nih.gov/35297436/
# 14  https://pubmed.ncbi.nlm.nih.gov/35282919/
# 15  https://pubmed.ncbi.nlm.nih.gov/35274925/
# 16  https://pubmed.ncbi.nlm.nih.gov/35266304/
# 17  https://pubmed.ncbi.nlm.nih.gov/35231149/
# 18  https://pubmed.ncbi.nlm.nih.gov/35215715/
# 19  https://pubmed.ncbi.nlm.nih.gov/35188864/
# 20  https://pubmed.ncbi.nlm.nih.gov/35181133/
# 21  https://pubmed.ncbi.nlm.nih.gov/35172240/
# 18              https://doi.org/10.3390/polym14040802
# 19      https://doi.org/10.1080/21655979.2022.2040876
# 20             https://doi.org/10.3168/jds.2021-21229
# 21       https://doi.org/10.1016/j.chroma.2022.462885
# 22               https://doi.org/10.3390/ijms23031492
# 23                  https://doi.org/10.3390/s22031111
# 24     https://doi.org/10.1016/j.ijbiomac.2022.01.183
# 25     https://doi.org/10.1016/j.foodchem.2022.132315
# 26     https://doi.org/10.1016/j.ijbiomac.2022.01.187
# 27                 https://doi.org/10.1002/btm2.10261
# 28         https://doi.org/10.1016/j.bbrc.2022.01.053
# 29    https://doi.org/10.1021/acsbiomaterials.1c01527
# 30       https://doi.org/10.1021/acs.analchem.1c04615
# 31           https://doi.org/10.1021/acs.jafc.1c06885
# 32       https://doi.org/10.1021/acs.analchem.1c03786
# 33               https://doi.org/10.1167/iovs.63.1.11
# 34         https://doi.org/10.1007/s11274-021-03206-z
# 35      https://doi.org/10.1016/j.carbpol.2021.118990
# 36     https://doi.org/10.1016/j.ijbiomac.2021.12.133
# 37    https://doi.org/10.1021/acsbiomaterials.1c01087
# 38         https://doi.org/10.1021/acs.biomac.1c01372
# 39             https://doi.org/10.1002/smll.202106363
# 40     https://doi.org/10.1016/j.biortech.2021.126534
# 41  https://doi.org/10.1016/j.anireprosci.2021.106889
# 42                  https://doi.org/10.1172/JCI151239
# 43   https://doi.org/10.1016/j.bioelechem.2021.108007
# 44                 https://doi.org/10.1039/d1tb01793d
# 45                 https://doi.org/10.1002/jemt.23992
# 46      https://doi.org/10.1016/j.jconrel.2021.11.027
# 47                  https://doi.org/10.1002/term.3263
# 48                 https://doi.org/10.4315/JFP-21-354
# 49                  https://doi.org/10.1111/lam.13596
# 50             https://doi.org/10.1002/advs.202104128
# 51     https://doi.org/10.1016/j.foodchem.2021.131439
# 52    https://doi.org/10.1016/j.enzmictec.2021.109907
# 53     https://doi.org/10.1016/j.foodchem.2021.130902
# 54                https://doi.org/10.1002/jbm.a.37272

# %%
# Función filtrado
def keywdFilter(row):
    
    # Palabras clave a filtrar
    keywds = [
        "univ.", "university", "universidad", "universitat", "università", "université", "universität",
        "school", "institute", "instituto", "institut", "hospital", "ministry"
    ]

    # Por cada fila del data frame, nos quedamos con la afiliación y las separamos por salto de línea
    aff = row.Affiliations.split("\n")
    goodAffs = [
        # para cada afiliación en aff ...
        affiliation for affiliation in aff
        # si no se cumple que ...
        if not(
            [
                kwd for kwd in keywds # para cada palabra clave en keywds añadimos la keywd ...
                if kwd in affiliation.lower() # si esta se encuentra en la afiliación
            ]
        )
    ]
    
    return bool(goodAffs)

# %% [markdown]
# Miramos aquellos resultados que pasan nuestro filtro:

# %%
dfPositive = df[df.apply(keywdFilter, axis=1)]
dfPositive
# Out:
#                                                 Title  NumAff  \
# 2   Poly-L-Lysine-Based αGal-Glycoconjugates for T...      12
# 3   A poly-l-lysine-bonded TEMPO-oxidized bacteria...       3
# 13  Blocking viral infections with lysine-based po...       3
# 17  Polylysine dendrigraft is able to differential...       4
# 29  Low-Molecular-Weight Polylysines with Excellen...       6
# 33  Amoebicidal Activity of Poly-Epsilon-Lysine Fu...       4
# 38  Development of Icephilic ACTIVE Glycopeptides ...       3
# 40  Facile and green synthesis of reduced graphene...       5
# 41  Utility of carboxylated poly L-lysine for the ...       4
# 42  Randomized trial of neoadjuvant vaccination wi...       9
#
#                                          Affiliations  \
# 2   MEGA: Asthma Inception and Progression Mechani...
# 3   Microbiological Engineering and Industrial Bio...
# 13  ViroStatics srl, Viale Umberto I, 46, 07100 Sa...
# 17  Laboratoire de Microbiologie Signaux et Microe...
# 29  Department of Ophthalmology, The Second Hospit...
# 33  Department of Eye and Vision Science, Institut...
# 38  School of Materials Science and Engineering, T...
# 40  College of Food Science and Light Industry, Na...
# 41  Kagoshima City Aquarium, Kagoshima, Japan.\nJo...
# 42  Department of Respiratory Medicine & Rheumatol...
#
#                                              Abstract  \
# 2   Anti-αGal IgE antibodies mediate a spreading a...
# 3   Oxidized bacterial nanocellulose (O-BNC) is a ...
# 13  The outbreak of the Covid-19 pandemic due to t...
# 17  With a view to reducing the impact of Cutibact...
# 29  The steady development of bacterial resistance...
# 33  To determine the amoebicidal activity of funct...
# 38  Ice formation and recrystallization exert seve...
# 40  Facile and green fabrication of reduced graphe...
# 41  Assisted reproduction techniques are required ...
# 42  BACKGROUNDLong-term prognosis of WHO grade II ...
#
#                                          PMID  \
# 2   https://pubmed.ncbi.nlm.nih.gov/35432370/
# 3   https://pubmed.ncbi.nlm.nih.gov/35422281/
# 13  https://pubmed.ncbi.nlm.nih.gov/35297436/
# 17  https://pubmed.ncbi.nlm.nih.gov/35231149/
# 29  https://pubmed.ncbi.nlm.nih.gov/35050580/
# 33  https://pubmed.ncbi.nlm.nih.gov/34994769/
# 38  https://pubmed.ncbi.nlm.nih.gov/34965723/
# 40  https://pubmed.ncbi.nlm.nih.gov/34896528/
# 41  https://pubmed.ncbi.nlm.nih.gov/34883419/
# 42  https://pubmed.ncbi.nlm.nih.gov/34882581/
#
#                                                   DOI
# 2           https://doi.org/10.3389/fimmu.2022.873019
# 3       https://doi.org/10.1016/j.carbpol.2022.119266
# 13                 https://doi.org/10.1039/d2bm00030j
# 17                  https://doi.org/10.1111/exd.14554
# 29    https://doi.org/10.1021/acsbiomaterials.1c01527
# 33               https://doi.org/10.1167/iovs.63.1.11
# 38         https://doi.org/10.1021/acs.biomac.1c01372
# 40     https://doi.org/10.1016/j.biortech.2021.126534
# 41  https://doi.org/10.1016/j.anireprosci.2021.106889
# 42                  https://doi.org/10.1172/JCI151239

# %% [markdown]
# Y también miramos aquellos resultados que no pasan nuestro filtro:

# %%
dfNegative = df[~df.apply(keywdFilter, axis=1)]
dfNegative
# Out:
#                                                 Title  NumAff  \
# 0   Development and characterization of levan/pull...       2
# 1   Long-Chain Poly-d-Lysines Interact with the Pl...       1
# 4   Effect of FLOT2 Gene Expression on Invasion an...       2
# 5   AdpA, a developmental regulator, promotes ε-po...       4
# 6   Antibacterial dialdehyde sodium alginate/ε-pol...       4
# 7   Effect of crosslinking strategy on the biologi...       4
# 8   Inkjet-Patterned Microdroplets as Individual M...       2
# 9   Construction of Intelligent Responsive Drug De...       5
# 10  Preparation and Properties of Pea Starch/ε-Pol...       2
# 11  Multi-omics reveals host metabolism associated...       1
# 12  Peptide-Engineered AIE Nanofibers with Excelle...       3
# 14  Structure, stability, rheology, and texture pr...       2
# 15  Poly-l-lysine/Laminin Surface Coating Reverses...       4
# 16  Synergetic integrations of bone marrow stem ce...       3
# 18  NIPAm-Based Modification of Poly(L-lysine): A ...       2
# 19  Poly(ε-L-lysine) and poly(L-diaminopropionic a...       2
# 20  A fluorescent biosensor based on quantum dot-l...       3
# 21  Open tubular nano-liquid chromatography with a...       3
# 22  Poly-L-Lysine-Lactobionic Acid-Capped Selenium...       1
# 23  Measurement of Secondary Structure Changes in ...       2
# 24  Starch/PBAT blown antimicrobial films based on...       2
# 25  Metabolomics analysis of freeze-thaw tolerance...       2
# 26  Preparation and characterization of bifunction...       4
# 27  Polylysine for skin regeneration: A review of ...      11
# 28  Crystal structure of the adenylation domain fr...       5
# 30  Wash-Free, Sandwich-Type Protein Detection Usi...       1
# 31  Fabrication of Epsilon-Polylysine-Based Magnet...       3
# 32  Poly-l-Lysine-Modified Graphene Field-Effect T...       2
# 34  Screening biofilm eradication activity of etha...       2
# 35  Low temperature extrusion blown ε-polylysine h...       4
# 36  Electrostatically self-assembled filamentous s...       6
# 37  Fabrication of Poly-l-lysine-Functionalized Gr...       1
# 39  Programmable Electrodeposition of Janus Algina...       4
# 43  Reversible electrochemical triggering and opti...       4
# 44  Investigating histidinylated highly branched p...       3
# 45  Chitosan utilized for bacterial preparation fo...       3
# 46  A spatiotemporal release platform based on pH/...       4
# 47  Anti-adhesive effect of chondrocyte-derived ex...       6
# 48  High Pressure Thermal Sterilization and ε-Poly...       1
# 49  Antibacterial activity and action mechanism of...       2
# 50  Precise Diabetic Wound Therapy: PLS Nanosphere...       3
# 51  Preparation and characterization of gelatin/ze...       4
# 52  Effects of ethanol stress on epsilon-poly-l-ly...       3
# 53  Microencapsulation of functional ovalbumin and...       3
# 54  Influence of enantiomeric polylysine grafted o...       1
#
#                                          Affiliations  \
# 0   College of Biomass Science and Engineering, Si...
# 1   State Key Laboratory of Bioelectronics, School...
# 4   Department of Gastrointestinal Surgery, The Fi...
# 5   Key Laboratory of Molecular Microbiology and T...
# 6   College of Chemistry and Environment Protectio...
# 7   AO Research Institute Davos, Clavadelerstrasse...
# 8   Department of Chemistry, Beijing Key Laborator...
# 9   Department of Respiratory Medicine, The First ...
# 10  School of Innovation & Entrepreneurship, Zheji...
# 11  Institute of Bast Fiber Crops, Chinese Academy...
# 12  Key Laboratory of Biomedical Engineering of Gu...
# 14  College of Food Science and Biotechnology Engi...
# 15  Univ. Grenoble Alps, CNRS, Grenoble INP, Insti...
# 16  Department of Sports Medicine and Joint Surger...
# 18  Department of Chemical Engineering, University...
# 19  School of Food Science and Pharmaceutical Engi...
# 20  Department of Analytical Chemistry, Faculty of...
# 21  Food Analysis and Research Laboratory, Bingöl ...
# 22  Nano-Gene and Drug Delivery Group, Discipline ...
# 23  Lehrstuhl für Technische Thermodynamik (LTT), ...
# 24  College of Food Science and Engineering, Shand...
# 25  State Key Laboratory of Food Science and Techn...
# 26  Key Laboratory of Carbohydrate Chemistry and B...
# 27  Medical Mycology and Bacteriology Research Cen...
# 28  Department of Chemistry and Biotechnology, Gra...
# 30  Department of Chemistry and Chemistry Institut...
# 31  College of Food Science and Engineering, North...
# 32  State Key Laboratory of Crystal Materials, Sha...
# 34  Fukuoka Industrial Technology Center, Biotechn...
# 35  Department of Food Science, University of Guel...
# 36  School of Perfume and Aroma Technology, Shangh...
# 37  Department of Pharmaceutical Chemistry, H. R. ...
# 39  Shenzhen Key Laboratory of Biomimetic Robotics...
# 43  Dept. Of Molecular, Cellular and Development B...
# 44  Division of Molecular Therapeutics and Formula...
# 45  Core Facilities of West China Hospital, Sichua...
# 46  Department of Orthopedics, Orthopedic Research...
# 47  Department of Orthopedic Surgery, School of Me...
# 48  School of Food and Wine Science, Ningxia Unive...
# 49  School of Food Science and Biotechnology, Zhej...
# 50  Department of Orthopedic Trauma, Renji Hospita...
# 51  Institute of Agricultural Products Processing,...
# 52  College of Food and Bioengineering, Henan Univ...
# 53  School of Life Sciences, Anhui University, Hef...
# 54  MOE Key Laboratory of Macromolecular Synthesis...
#
#                                              Abstract  \
# 0   The levan/pullulan/chitosan edible films, enri...
# 1   Polylysines have been frequently used in drug ...
# 4   The study is aimed at investigating the effect...
# 5   AdpA is a global regulator of morphological di...
# 6   Food security is an important global public he...
# 7   The design of multifunctional hydrogels based ...
# 8   Adhesion of single cells is the foundation of ...
# 9   Cancer remains a formidable global problem wit...
# 10  The composite films comprising pea starch (St)...
# 11  This study aimed to assess the influence of di...
# 12  Photosensitizers with aggregation-induced emis...
# 14  ε-Polylysine (ε-PL) is a natural preservative ...
# 15  Brain tissues demonstrate heterogeneous mechan...
# 16  The cartilage repair and regeneration show ina...
# 18  Polylysine is a biocompatible, biodegradable, ...
# 19  Poly(ε-L-lysine) and poly(L-diaminopropionic a...
# 20  Salmonella, as a common foodborne pathogen in ...
# 21  In this study, a novel narrow capillary (i.e.,...
# 22  Liver cancer is currently regarded as the seco...
# 23  Drying processes such as spray drying, as comm...
# 24  In this study, starch/PBAT antimicrobial film,...
# 25  Antimicrobial polycationic peptide ε-poly-l-ly...
# 26  A gellan-polylysine (GPL) fiber was prepared b...
# 27  There have been several attempts to find promi...
# 28  ε-poly-l-lysine (ε-PL) synthetase (Pls) is a m...
# 30  Direct electron transfer (DET) between a redox...
# 31  The risk of fruit juice contamination caused b...
# 32  (Mi)RNAs are important biomarkers for cancers ...
# 34  The ethanol extracts of 155 different foodstuf...
# 35  Edible antimicrobial films made from starch/ge...
